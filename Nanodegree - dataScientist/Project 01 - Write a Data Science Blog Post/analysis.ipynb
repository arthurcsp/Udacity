# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Questions to be answered:
#
# 1- Which tools are commoly used by data scientist and how they related to salary?
#
# 2- Are there Diferent salaries by ethnicity, Gender or Sexuality?
#
# 3- Which country and region pays more?

# %%
df = pd.read_csv('survey_results_public.csv')

# %%
fruit_info = { 'fruit': 'apple', 'count': 2, 'price': 3.5 }

# %%
# comment

# %%
df = df.dropna(subset=['ConvertedCompYearly'], axis=0).rename(columns={'ConvertedCompYearly':'Salary'})

# %%
df['Salary'].hist()
# Out:
# <AxesSubplot:>

# %%
df[df.columns[df.isna().mean() <0.3]]
# Out:
#        ResponseId                      MainBranch  \
# 0               1  I am a developer by profession
# 9              10  I am a developer by profession
# 11             12  I am a developer by profession
# 12             13  I am a developer by profession
# 16             17  I am a developer by profession
# ...           ...                             ...
# 83434       83435  I am a developer by profession
# 83435       83436  I am a developer by profession
# 83436       83437  I am a developer by profession
# 83437       83438  I am a developer by profession
# 83438       83439  I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# 9                                     Employed full-time
# 11                                    Employed full-time
# 12                                    Employed full-time
# 16                                    Employed full-time
# ...

# %%
df.groupby('Country')['Salary'].mean().sort_values(ascending=False)
# Out:
# Country
# Afghanistan                 2.794748e+06
# San Marino                  5.967000e+05
# United States of America    2.629939e+05
# North Korea                 2.400000e+05
# Nomadic                     2.154913e+05
#                                 ...
# Yemen                       5.628667e+03
# Botswana                    5.384000e+03
# Guinea                      5.064000e+03
# Burundi                     1.584000e+03
# Liberia                     1.200000e+01
# Name: Salary, Length: 171, dtype: float64
